# %%
#@title Installation of Sherlock
#@markdown https://github.com/sherlock-project/sherlock


# https://github.com/sherlock-project/sherlock
# clone the repo
# !git clone https://github.com/sherlock-project/sherlock.git
# %cd sherlock
# !cd doesnt work https://stackoverflow.com/questions/48298146/changing-directory-in-google-colab-breaking-out-of-the-python-interpreter
# !python3 -m pip install -r requirements.txt -q

# %%
#@title Insert your username
#@markdown Stalk yourself (please dont)

username = 'poggers'  #@param
# !python3 sherlock $username
# Out:
# [*] Checking username poggers on:
# [+] 500px: https://500px.com/p/poggers
# [+] 7Cups: https://www.7cups.com/@poggers
# [+] 9GAG: https://www.9gag.com/u/poggers
# [+] Academia.edu: https://independent.academia.edu/poggers
# [+] Alik.cz: https://www.alik.cz/u/poggers
# [+] Archive.org: https://archive.org/details/@poggers
# [+] AskFM: https://ask.fm/poggers
# [+] BLIP.fm: https://blip.fm/poggers
# [+] Badoo: https://badoo.com/profile/poggers
# [+] Bandcamp: https://www.bandcamp.com/poggers
# [+] Behance: https://www.behance.net/poggers
# [+] BitBucket: https://bitbucket.org/poggers/
# [+] Blogger: https://poggers.blogspot.com
# [+] BodyBuilding: https://bodyspace.bodybuilding.com/poggers
# [+] BuzzFeed: https://buzzfeed.com/poggers
# [+] CNET: https://www.cnet.com/profiles/poggers/
# [+] Chess: https://www.chess.com/member/poggers
# [+] Codecademy: https://www.codecademy.com/profiles/poggers
# [+] Codewars: https://www.codewars.com/users/poggers
# ...
